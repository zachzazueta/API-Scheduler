# %%
import pandas as pd 
import requests
import time
import datetime

starttime=time.time()
count=0
j = pd.DataFrame(columns=['station_id', 'num_bikes_available', 
                          'num_ebikes_available', 'num_bikes_disabled', 
                          'num_docks_available', 'num_docks_disabled', 
                          'is_installed', 'is_renting', 'is_returning', 
                          'last_reported', 'eightd_has_available_keys'])
while count<40:
    resp = requests.get('https://gbfs.citibikenyc.com/gbfs/en/station_status.json')
    response = resp.json()
    for i in response['data']['stations']:
        currentDT = datetime.datetime.now()
        i['time_pulled'] = currentDT.strftime("%Y-%m-%d %H:%M:%S")
        j = j.append(i, ignore_index=True)
    time.sleep(900.0 - ((time.time() - starttime) % 900.0))
    count+=1

j.head(10)
# Out:
#   station_id num_bikes_available num_ebikes_available num_bikes_disabled  \
# 0         72                  11                    0                  0
# 1         79                  17                    0                  1
# 2         82                  25                    0                  1
# 3         83                  53                    2                  0
# 4        116                  20                    1                  0
# 5        119                  32                    0                  2
# 6        120                   4                    1                  0
# 7        127                  15                    2                  1
# 8        128                  44                    1                  0
# 9        143                   7                    1                  1
#
#   num_docks_available num_docks_disabled is_installed is_renting is_returning  \
# 0                  44                  0            1          1            1
# 1                  15                  0            1          1            1
# 2                   1                  0            1          1            1
# 3                   9                  0            1          1            1
# 4                  29                  0            1          1            1
# 5                  19                  0            1          1            1
# 6                  15                  0            1          1            1
# 7                  15                  0            1          1            1
# 8                  12                  0            1          1            1
# 9                  16                  0            1          1            1
#
#   last_reported eightd_has_available_keys legacy_id station_status  \
# 0    1607129358                     False        72         active
# 1    1607128376                     False        79         active
# 2    1607129620                     False        82         active
# 3    1607129844                     False        83         active
# 4    1607129192                     False       116         active
# 5    1607126711                     False       119         active
# 6    1607126347                     False       120         active
# 7    1607130063                     False       127         active
# 8    1607130113                     False       128         active
# 9    1607130202                     False       143         active
#
#            time_pulled
# 0  2020-12-04 20:04:06
# 1  2020-12-04 20:04:06
# 2  2020-12-04 20:04:06
# 3  2020-12-04 20:04:06
# 4  2020-12-04 20:04:06
# 5  2020-12-04 20:04:06
# 6  2020-12-04 20:04:06
# 7  2020-12-04 20:04:06
# 8  2020-12-04 20:04:06
# 9  2020-12-04 20:04:06
